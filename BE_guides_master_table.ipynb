# %%
import numpy as np
import pandas as pd
from datascience import *

# %%
LDLR_file_path = '/Users/allisonjames/Documents/Rotations/Sherwood Lab/BE screens/LDLR_table2.txt'
SREBF2_file_path = '/Users/allisonjames/Documents/Rotations/Sherwood Lab/BE screens/SREBF2_table.txt'
HNF4A_file_path = '/Users/allisonjames/Documents/Rotations/Sherwood Lab/BE screens/HNF4A_table.txt'
MYLIP_file_path = '/Users/allisonjames/Documents/Rotations/Sherwood Lab/BE screens/MYLIP_table.txt'
ACAT2_file_path = '/Users/allisonjames/Documents/Rotations/Sherwood Lab/BE screens/ACAT2_table.txt'
LSS_file_path = '/Users/allisonjames/Documents/Rotations/Sherwood Lab/BE screens/LSS_table.txt'
pd.set_option('display.max_columns', None)

# %%
def get_SA_guides(gene, file_path):
    table = pd.read_csv(file_path, sep='\t')
    entry_1 = table.iloc[0]
    starts = entry_1.loc["exonStarts"].strip(", ").split(',')
    start1 = []
    for i in starts:
        start1 = np.append(start1, int(i)-8)
    start2 = start1+1
    start3 = start1+2
    start4 = start1+3
    start5 = start1+4
    stop1 = start1+19
    stop2 = start2+19
    stop3 = start3+19
    stop4 = start4+19  
    stop5 = start5+19
    guide1 = []
    guide2 = []
    guide3 = []
    guide4 = []
    guide5 = []
    for i in np.arange(len(start1)):
        guide1 = np.append(guide1, entry_1["chrom"]+":"+str(int(start1[i]))+"-"+str(int(stop1[i])))
        guide2 = np.append(guide2, entry_1["chrom"]+":"+str(int(start2[i]))+"-"+str(int(stop2[i])))
        guide3 = np.append(guide3, entry_1["chrom"]+":"+str(int(start3[i]))+"-"+str(int(stop3[i])))
        guide4 = np.append(guide4, entry_1["chrom"]+":"+str(int(start4[i]))+"-"+str(int(stop4[i])))
        guide5 = np.append(guide5, entry_1["chrom"]+":"+str(int(start5[i]))+"-"+str(int(stop5[i])))
    
    guide_positions = pd.DataFrame({"gene": gene, "site": "splice acceptor", "strand":"+", "chromosome":entry_1["chrom"].strip("chr"),"BE": "ABE", "guide1":guide1 , "guide2":guide2, "guide3":guide3, "guide4":guide4, "guide5":guide5})
    return guide_positions

def get_SD_guides(gene, file_path):
    table = pd.read_csv(file_path, sep='\t')
    entry_1 = table.iloc[0]
    ends = entry_1.loc["exonEnds"].strip(", ").split(',')
    start1 = []
    for i in ends:
        start1 = np.append(start1, int(i)-10)
    start2 = start1-1
    start3 = start1-2
    start4 = start1-3
    start5 = start1-4
    stop1 = start1+19
    stop2 = start2+19
    stop3 = start3+19
    stop4 = start4+19  
    stop5 = start5+19
    guide1 = []
    guide2 = []
    guide3 = []
    guide4 = []
    guide5 = []
    for i in np.arange(len(start1)):
        guide1 = np.append(guide1, entry_1["chrom"]+":"+str(int(start1[i]))+"-"+str(int(stop1[i])))
        guide2 = np.append(guide2, entry_1["chrom"]+":"+str(int(start2[i]))+"-"+str(int(stop2[i])))
        guide3 = np.append(guide3, entry_1["chrom"]+":"+str(int(start3[i]))+"-"+str(int(stop3[i])))
        guide4 = np.append(guide4, entry_1["chrom"]+":"+str(int(start4[i]))+"-"+str(int(stop4[i])))
        guide5 = np.append(guide5, entry_1["chrom"]+":"+str(int(start5[i]))+"-"+str(int(stop5[i])))
    
    guide_positions = pd.DataFrame({"gene": gene, "site": "splice donor", "strand":"-", "chromosome":entry_1["chrom"].strip("chr"), "BE": "ABE", "guide1":guide1 , "guide2":guide2, "guide3":guide3, "guide4":guide4, "guide5":guide5})
    return guide_positions

# %%
def get_guides(gene, file_path):
    SA_guides = get_SA_guides(gene, file_path)
    SD_guides = get_SD_guides(gene, file_path)
    master_table = SA_guides.append(SD_guides)
    return master_table

# %% [markdown]
# **ABE Controls**

# %% [markdown]
# *LDLR*

# %%
LDLR = get_guides("LDLR", LDLR_file_path)

# %%
LDLR
# Out:
#     gene             site strand chromosome   BE                   guide1  \
# 0   LDLR  splice acceptor      +         19  ABE  chr19:11089540-11089559
# 1   LDLR  splice acceptor      +         19  ABE  chr19:11100214-11100233
# 2   LDLR  splice acceptor      +         19  ABE  chr19:11102655-11102674
# 3   LDLR  splice acceptor      +         19  ABE  chr19:11105211-11105230
# 4   LDLR  splice acceptor      +         19  ABE  chr19:11106556-11106575
# 5   LDLR  splice acceptor      +         19  ABE  chr19:11107383-11107402
# 6   LDLR  splice acceptor      +         19  ABE  chr19:11110643-11110662
# 7   LDLR  splice acceptor      +         19  ABE  chr19:11111505-11111524
# 8   LDLR  splice acceptor      +         19  ABE  chr19:11113269-11113288
# 9   LDLR  splice acceptor      +         19  ABE  chr19:11113526-11113545
# 10  LDLR  splice acceptor      +         19  ABE  chr19:11116085-11116104
# 11  LDLR  splice acceptor      +         19  ABE  chr19:11116850-11116869
# 12  LDLR  splice acceptor      +         19  ABE  chr19:11120083-11120102
# 13  LDLR  splice acceptor      +         19  ABE  chr19:11120361-11120380
# 14  LDLR  splice acceptor      +         19  ABE  chr19:11123165-11123184
# 15  LDLR  splice acceptor      +         19  ABE  chr19:11127999-11128018
# 16  LDLR  splice acceptor      +         19  ABE  chr19:11129504-11129523
# 17  LDLR  splice acceptor      +         19  ABE  chr19:11131278-11131297
# 0   LDLR     splice donor      -         19  ABE  chr19:11089605-11089624
# 1   LDLR     splice donor      -         19  ABE  chr19:11100335-11100354
# 2   LDLR     splice donor      -         19  ABE  chr19:11102776-11102795
# 3   LDLR     splice donor      -         19  ABE  chr19:11105590-11105609
# 4   LDLR     splice donor      -         19  ABE  chr19:11106677-11106696
# 5   LDLR     splice donor      -         19  ABE  chr19:11107504-11107523
# 6   LDLR     splice donor      -         19  ABE  chr19:11110761-11110780
# 7   LDLR     splice donor      -         19  ABE  chr19:11111629-11111648
# 8   LDLR     splice donor      -         19  ABE  chr19:11113439-11113458
# 9   LDLR     splice donor      -         19  ABE  chr19:11113752-11113771
# 10  LDLR     splice donor      -         19  ABE  chr19:11116202-11116221
# 11  LDLR     splice donor      -         19  ABE  chr19:11116988-11117007
# 12  LDLR     splice donor      -         19  ABE  chr19:11120223-11120242
# 13  LDLR     splice donor      -         19  ABE  chr19:11120512-11120531
# 16  chr19:11129659-11129678  chr19:11129658-11129677  chr19:11129657-11129676
# 17  chr19:11131305-11131324  chr19:11131304-11131323  chr19:11131303-11131322
#
#                      guide5
# 0   chr19:11089544-11089563
# 1   chr19:11100218-11100237
# 2   chr19:11102659-11102678
# 3   chr19:11105215-11105234
# 4   chr19:11106560-11106579
# 5   chr19:11107387-11107406
# 6   chr19:11110647-11110666
# 7   chr19:11111509-11111528
# 8   chr19:11113273-11113292
# 9   chr19:11113530-11113549
# 10  chr19:11116089-11116108
# 11  chr19:11116854-11116873
# 12  chr19:11120087-11120106
# 13  chr19:11120365-11120384
# 14  chr19:11123169-11123188
# 15  chr19:11128003-11128022
# 16  chr19:11129508-11129527
# 17  chr19:11131282-11131301
# 0   chr19:11089601-11089620
# 1   chr19:11100331-11100350
# 2   chr19:11102772-11102791
# 3   chr19:11105586-11105605
# 4   chr19:11106673-11106692
# 5   chr19:11107500-11107519
# 6   chr19:11110757-11110776
# 7   chr19:11111625-11111644
# 8   chr19:11113435-11113454
# 9   chr19:11113748-11113767
# 10  chr19:11116198-11116217
# 11  chr19:11116984-11117003
# 12  chr19:11120219-11120238
# 13  chr19:11120508-11120527
# 14  chr19:11123330-11123349
# 15  chr19:11128071-11128090
# 16  chr19:11129656-11129675
# 17  chr19:11131302-11131321

# %% [markdown]
# *SREBF2*

# %%
SREBF2 = get_guides("SREBF2", SREBF2_file_path)

# %% [markdown]
# *HNF4A*

# %%
HNF4A = get_guides("HNF4A", HNF4A_file_path)

# %% [markdown]
# *MYLIP*

# %%
MYLIP = get_guides("MYLIP", MYLIP_file_path)

# %% [markdown]
# *ACAT2*

# %%
ACAT2 = get_guides("ACAT2", ACAT2_file_path)

# %% [markdown]
# *LSS*

# %%
LSS = get_guides("LSS", LSS_file_path)

# %%
LSS
# Out:
#    gene             site strand chromosome   BE                   guide1  \
# 0   LSS  splice acceptor      +         21  ABE  chr21:46191094-46191113
# 1   LSS  splice acceptor      +         21  ABE  chr21:46191871-46191890
# 2   LSS  splice acceptor      +         21  ABE  chr21:46194481-46194500
# 3   LSS  splice acceptor      +         21  ABE  chr21:46195666-46195685
# 4   LSS  splice acceptor      +         21  ABE  chr21:46196192-46196211
# 5   LSS  splice acceptor      +         21  ABE  chr21:46205826-46205845
# 6   LSS  splice acceptor      +         21  ABE  chr21:46206662-46206681
# 7   LSS  splice acceptor      +         21  ABE  chr21:46207418-46207437
# 8   LSS  splice acceptor      +         21  ABE  chr21:46208241-46208260
# 9   LSS  splice acceptor      +         21  ABE  chr21:46209544-46209563
# 10  LSS  splice acceptor      +         21  ABE  chr21:46210678-46210697
# 11  LSS  splice acceptor      +         21  ABE  chr21:46213015-46213034
# 12  LSS  splice acceptor      +         21  ABE  chr21:46213728-46213747
# 13  LSS  splice acceptor      +         21  ABE  chr21:46215170-46215189
# 14  LSS  splice acceptor      +         21  ABE  chr21:46215675-46215694
# 15  LSS  splice acceptor      +         21  ABE  chr21:46216379-46216398
# 16  LSS  splice acceptor      +         21  ABE  chr21:46219466-46219485
